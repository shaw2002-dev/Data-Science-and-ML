# %%
"""
LOGISTIC REGRESSION CONTINUED....

Accuracy = (TP+TN)/(TP+TN+FP+FN)

Precision = TP/TP+FP

Recall = TP/TP+FN

F-Beta Score = (1+Beta^2)*Precision*Recall/(Beta^2*Precision)+Recall

where, value of Beta = 0.5, 1, 2

0.5 --> Precision is more important than Recall
1 --> Precision and Recall are equally important
2 --> Recall is more important than Precision


PRECISION EXAMPLE -> Being wrong but that wrong is a big issue we can use this

You have made a model for Cancer prediction

A man is tested for cancer from your machine
That man do not have cancer, but your machine predicts he has cancer  --> FP
That man has cancer, but your machine predicts he does not have cancer --> FN


RECALL EXAMPLE -> Being wrong but that wrong is not a big issue we can use this

Suppose you have an alarm system for Earthquake

Alarm rang but earthquake do not come --> FN

Alarm did not rang but earthquake came --> FP

"""

# %%
"""
DECISION TREE -> Used to solve both regression and classification based problem.

Core Functionality of DT is splitting the dataset.

Different types/elements of Decision Tree are:

1) Root Node: Parent Node which will contain all the training data.
2) Decision Nodes: nodes from root node on which conditions have been applied.
3) Leaf Node: Final node on which no splitting can happen.

Regression: mean value
Classification: mode value(Majority voting)

Cost Function:

For Classification
Gini Impurity -->  1-Gini   where, Gini = p1^2 + p2^2 (p1,p2 are probabilities)

Information Gain(IG) --> -p1log(p1)-p2log(p2)

For Regression
x^2

Evaluation Metrics: Same as Classification and Regression

"""

# %%
"""
Ensemble Technique: You are training more than 1 model.

 Types of Ensemble Technique are:
      1. Bagging : All the models will be trained parallely.
      2. Boosting : models are trained sequencely.

The result of each model is combined to form the final result of the model.

"""

# %%
"""
RANDOM FOREST - Multiple decision trees are trained in parallel.

Classification : DT1   DT2   DT3   DT4  DT5  DT6  DT7  Final result will be mode
                  0     1     0     0    1    1    0               0

Regression : DT1   DT2   DT3   DT4   DT5    DT6   DT7  Final result will be mean
              2   2.25   2.2  2.15  2.176  2.54  2.34         2.236571429

"""

# %%
"""
XgBOOT - Multiple decision trees are trained sequencially.
        current model will be dependent on previous model.

Wokring Principle: The residue of DT1 becomes the label for the DT2 and so on...

Example:  Suppose House Prediction

           y              DT1(y1_pred)     Residue(abs(y-DT1))     DT2       abs(Residue-DT2)      DT3        Final_prediction(DT1+DT2+DT3)

           4                   3                   1               0.7              0.3            0.1                      3.8
           5                  4.5                 0.5              0.4              0.1           0.15                     5.05
          2.5                  1                  1.5              1.6              0.1            0.1                      2.7
           6                  5.6                 0.4             0.45             0.05           0.04                     6.09

GradientBoosting Algorithm: Squared Error

"""
