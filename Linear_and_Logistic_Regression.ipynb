# %%
"""
LINEAR REGRESSION CONTINUED....

y = mx+c    where, m---> decides the importance of the feature in calculating the target.

(Range of straight line is from -inf to +inf)

                    m             0                            200
                    c             0                             10

feature              Target   y = 0                        y = 200x+10

hours_worked         salary   y_pred      (y-y_pred)^2        y_pred     (y-y_pred)^2

   1.2                300       0            90000             200           2500
   1.5                350       0           120000             310           1600
   2.1                370       0           136900             430           3600
   3                  400       0           160000             610          44100
   4                  470       0           220900             810         115600
   5                  550       0           302500            1010         211600
   5.5                700       0           490000            1110         168100

                               sum    =>   1522800                         547100

Gradient Descent -> Optimization algorithm used to train ML models by minimizing errors between prediction and actual values.

"""

# %%
"""
y_actual         y_pred             MSE           MAE         TSS

  300             400              10000          100      22073.4694
  350             250              10000          100      9716.32653
  370             150              48400          220      6173.46939
  400             200              40000          200      2359.18367
  470             350              14400          120      459.183673
  550             600               2500           50      10287.7551
  700            1000              90000          300      63216.3265

                 mean    =>      30757.1429     155.7143   114285.714
                  SSR    =>        215300
                 RMSE    =>      175.377145

- MSE,RMSE,MAE basically tells the error made by the model.
- R2, Adj R2 will be used to compare the models.

R2 = 1-(SSR/TSS)  =>  -0.883875 (R2 will never be greater than 1 but it can be less than 0 which means your model has performed extremely bad)

Range of R2 will be from 0-1.

where,

SSR = sum of squares of residuals -> sum(y_pred-y_actual)^2
TSS = total sum of squares -> sum(y_actual - y_mean)^2

Adj R2 = 1-((1-R^2)(n-1)/(n-p-1))

where,

n = total no. of rows
p = total no. of features

"""

# %%
 """
 LOGISTIC REGRESSION

1) Core Functionality: Sigmoid Function (Range of sigmoid function is 0-1)

    y = 1/(1+e^-z)  where, z = mx+c      <0.5 -> 0
                                         >0.5 -> 1

2) Parameters:  m,c

3) Cost Function:  Log Loss Function/Binary crossentropy
                         -ylog(y_pred))-(1-y)log(1-y_pred)

4) Evaluation Metrics: Accuracy, Precision, Recall, F-Beta score
