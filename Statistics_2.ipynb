# %%
"""
Quantile - dividing your data into equal parts.

Types of Quantiles:
  - Quartile = Dividing data into 4 equal parts.
  - Decile = Dividing data into 10 equal parts.
  - Percentile = Dividing data into 100 equal parts.
  - Quintile = Dividing data into 5 equal parts.

"""

# %%
"""
CoVariance = (sum(x-x_mean)(y-y_mean))/N ----> Population
           = (sum(x-x_mean)(y-y_mean))/n-1 --> Sample

Correlation = cov(x,y)/SD(x)*SD(y),  Range of Correlation = [-1,1]

[-1,-0.8] ---> Strong correlation
[-0.8,-0.4] ---> Moderate correlation
[-0.4,0.4] ---> Weak correlation
[0.4,0.8] ---> Moderate correlation
[0.8,1] ---> Strong correlation

"""
